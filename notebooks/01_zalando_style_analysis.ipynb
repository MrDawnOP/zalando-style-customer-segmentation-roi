# %% [markdown]
# # Zalando-Style Customer Segmentation and Marketing ROI Analysis
# Recruiter-ready walkthrough of the generated portfolio project.

# %%
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt
BASE=Path('..')
P=BASE/'data'/'processed'
customers=pd.read_csv(P/'customers_clean.csv')
orders=pd.read_csv(P/'orders_clean.csv')
campaigns=pd.read_csv(P/'campaigns_clean.csv')
channel_kpis=pd.read_csv(P/'marketing_kpis_by_channel.csv')
segment_performance=pd.read_csv(P/'segment_performance.csv')
customers.head()

# %%
pd.read_csv(P/'executive_summary_table.csv')

# %%
channel_kpis.sort_values('roas', ascending=False)[['channel','total_spend','total_revenue','roas','roi','cpa','conversion_rate']]

# %%
segment_performance.sort_values('revenue', ascending=False)

# %%
pd.read_csv(P/'budget_reallocation.csv')

# %%
monthly=pd.read_csv(P/'monthly_revenue.csv')
ax=monthly.plot(x='order_month', y='revenue', marker='o', legend=False)
ax.set_title('Monthly Revenue Trend')
ax.set_xlabel('Order Month')
ax.set_ylabel('Revenue')
plt.xticks(rotation=45)
plt.tight_layout()
